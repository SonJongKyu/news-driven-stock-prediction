# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from urllib.parse import quote
import random
import re

# 기업 리스트
companies = ["세진중공업"]

# 날짜 리스트
dates = pd.date_range(start="2020-01-01", end="2024-12-31").strftime("%Y.%m.%d").tolist()

# 결과 저장용
results = []
seen = set()

# Chrome 옵션 설정
options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# 드라이버 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# 크롤링 시작
for company in companies:
    print(f"\n🔍 [기업 시작] {company}")
    encoded_query = quote(company)

    for target_date in dates:
        print(f"   📅 [날짜 처리 중] {target_date}")
        display_date = target_date.replace(".", "")
        count_per_day = 0

        for start in range(1, 1000, 10):
            url = (
                f"https://search.naver.com/search.naver?where=news&query={encoded_query}"
                f"&sort=0&ds={target_date}&de={target_date}"
                f"&nso=so:r,p:from{display_date}to{display_date},a:all"
                f"&start={start}"
            )

            driver.get(url)
            time.sleep(random.uniform(2, 4))  # 페이지 로딩 대기

            try:
                # 뉴스 기사 링크는 보통 외부 링크이며 target="_blank"를 가짐
                news_elements = driver.find_elements(By.CSS_SELECTOR, 'a[target="_blank"]')
            except Exception as e:
                print(f"      ⚠️ 구조 탐색 실패 - {company} / {target_date} - {e}")
                break

            if not news_elements:
                break  # 뉴스 없으면 다음 날짜로

            for elem in news_elements:
                try:
                    href = elem.get_attribute("href")
                    if not href or "news" not in href:
                        continue  # 뉴스 관련 URL만 필터링

                    # 자식 span 태그에서 제목 추출
                    try:
                        span = elem.find_element(By.TAG_NAME, "span")
                        raw_title = span.get_attribute("textContent").strip()
                    except:
                        continue

                    # 제목 전처리
                    cleaned_title = re.sub(r'\[.*?\]', '', raw_title).strip()
                    cleaned_title = cleaned_title.replace(company, "").strip(", ").strip()

                    if not cleaned_title:
                        continue

                    if (company, cleaned_title, href) in seen:
                        continue
                    seen.add((company, cleaned_title, href))

                    results.append({
                        "기업명": company,
                        "날짜": target_date,
                        "뉴스제목": cleaned_title,
                        "URL": href
                    })
                    count_per_day += 1

                except Exception as e:
                    print(f"      ⚠️ 추출 오류: {e}")
                    continue

            if count_per_day == 0:
                break  # 해당 페이지 이후엔 더 이상 뉴스 없음

        if count_per_day > 0:
            print(f"   ✅ [수집 완료] {target_date} - {count_per_day}건")

        time.sleep(random.uniform(1, 2))  # 날짜 간 대기

    print("🌙 [대기] 다음 기업 전환 전 10초 대기...")
    time.sleep(10)

# 드라이버 종료
driver.quit()

# 저장
output_filename = f"{companies[0]}_뉴스.csv"
df = pd.DataFrame(results)
df.to_csv(output_filename, index=False, encoding='utf-8-sig')
print(f"\n📁 전체 완료! 총 {len(df)}건의 뉴스가 저장되었습니다: {output_filename}")
# Out:
# 🔍 [기업 시작] 세진중공업
#    📅 [날짜 처리 중] 2024.01.01
#    ✅ [수집 완료] 2024.01.01 - 3건
#    📅 [날짜 처리 중] 2024.01.02
#    ✅ [수집 완료] 2024.01.02 - 3건
#    📅 [날짜 처리 중] 2024.01.03
#    ✅ [수집 완료] 2024.01.03 - 8건
#    📅 [날짜 처리 중] 2024.01.04
#    ✅ [수집 완료] 2024.01.04 - 2건
#    📅 [날짜 처리 중] 2024.01.05
#    📅 [날짜 처리 중] 2024.01.06
#    📅 [날짜 처리 중] 2024.01.07
#    📅 [날짜 처리 중] 2024.01.08
#    ✅ [수집 완료] 2024.01.08 - 3건
#    📅 [날짜 처리 중] 2024.01.09
#    ✅ [수집 완료] 2024.01.09 - 11건
#    📅 [날짜 처리 중] 2024.01.10
#    ✅ [수집 완료] 2024.01.10 - 4건
#    📅 [날짜 처리 중] 2024.01.11
#    📅 [날짜 처리 중] 2024.01.12
#    ✅ [수집 완료] 2024.01.12 - 6건
#    📅 [날짜 처리 중] 2024.01.13
#    ✅ [수집 완료] 2024.01.13 - 1건
#    📅 [날짜 처리 중] 2024.01.14
#    ✅ [수집 완료] 2024.01.14 - 1건
#    📅 [날짜 처리 중] 2024.01.15
#    ✅ [수집 완료] 2024.01.15 - 4건
#    📅 [날짜 처리 중] 2024.01.16
#    ✅ [수집 완료] 2024.01.16 - 1건
#    📅 [날짜 처리 중] 2024.01.17
#    ✅ [수집 완료] 2024.01.17 - 1건
#    📅 [날짜 처리 중] 2024.01.18
#    📅 [날짜 처리 중] 2024.01.19
#    ✅ [수집 완료] 2024.01.19 - 2건
#    📅 [날짜 처리 중] 2024.01.20
#    📅 [날짜 처리 중] 2024.01.21
#    📅 [날짜 처리 중] 2024.01.22
#    ✅ [수집 완료] 2024.01.22 - 1건
#    📅 [날짜 처리 중] 2024.01.23
#    ✅ [수집 완료] 2024.01.23 - 2건
#    📅 [날짜 처리 중] 2024.01.24
#    ✅ [수집 완료] 2024.01.24 - 1건
#    📅 [날짜 처리 중] 2024.01.25
#    ✅ [수집 완료] 2024.01.25 - 1건
#    📅 [날짜 처리 중] 2024.01.26
#    ✅ [수집 완료] 2024.01.26 - 3건
#    📅 [날짜 처리 중] 2024.01.27
#    📅 [날짜 처리 중] 2024.01.28
#    📅 [날짜 처리 중] 2024.01.29
#    ✅ [수집 완료] 2024.01.29 - 1건
#    📅 [날짜 처리 중] 2024.01.30
#    📅 [날짜 처리 중] 2024.01.31
#    ✅ [수집 완료] 2024.01.31 - 2건
#    📅 [날짜 처리 중] 2024.02.01
#    📅 [날짜 처리 중] 2024.02.02
#    ✅ [수집 완료] 2024.02.02 - 8건
#    📅 [날짜 처리 중] 2024.02.03
#    📅 [날짜 처리 중] 2024.02.04
#    📅 [날짜 처리 중] 2024.02.05
#    ✅ [수집 완료] 2024.02.05 - 1건
#    📅 [날짜 처리 중] 2024.02.06
#    ✅ [수집 완료] 2024.02.06 - 2건
#    📅 [날짜 처리 중] 2024.02.07
#    ✅ [수집 완료] 2024.02.07 - 3건
#    📅 [날짜 처리 중] 2024.02.08
#    📅 [날짜 처리 중] 2024.02.09
#    📅 [날짜 처리 중] 2024.02.10
#    📅 [날짜 처리 중] 2024.02.11
#    ✅ [수집 완료] 2024.02.11 - 1건
#    📅 [날짜 처리 중] 2024.02.12
#    ✅ [수집 완료] 2024.02.12 - 1건
#    📅 [날짜 처리 중] 2024.02.13
#    ✅ [수집 완료] 2024.02.13 - 3건
#    📅 [날짜 처리 중] 2024.02.14
#    ✅ [수집 완료] 2024.02.14 - 1건
#    📅 [날짜 처리 중] 2024.02.15
#    📅 [날짜 처리 중] 2024.02.16
#    ✅ [수집 완료] 2024.02.16 - 1건
#    📅 [날짜 처리 중] 2024.02.17
#    📅 [날짜 처리 중] 2024.02.18
#    📅 [날짜 처리 중] 2024.02.19
#    📅 [날짜 처리 중] 2024.02.20
#    📅 [날짜 처리 중] 2024.02.21
#    ✅ [수집 완료] 2024.02.21 - 3건
#    📅 [날짜 처리 중] 2024.02.22
#    ✅ [수집 완료] 2024.02.22 - 1건
#    📅 [날짜 처리 중] 2024.02.23
#    ✅ [수집 완료] 2024.02.23 - 1건
#    📅 [날짜 처리 중] 2024.02.24
#    📅 [날짜 처리 중] 2024.02.25
#    📅 [날짜 처리 중] 2024.02.26
#    ✅ [수집 완료] 2024.02.26 - 3건
#    📅 [날짜 처리 중] 2024.02.27
#    ✅ [수집 완료] 2024.02.27 - 4건
#    📅 [날짜 처리 중] 2024.02.28
#    ✅ [수집 완료] 2024.02.28 - 3건
#    📅 [날짜 처리 중] 2024.02.29
#    ✅ [수집 완료] 2024.02.29 - 4건
#    📅 [날짜 처리 중] 2024.03.01
#    ✅ [수집 완료] 2024.03.01 - 2건
#    📅 [날짜 처리 중] 2024.03.02
#    📅 [날짜 처리 중] 2024.03.03
#    📅 [날짜 처리 중] 2024.03.04
#    ✅ [수집 완료] 2024.03.04 - 2건
#    📅 [날짜 처리 중] 2024.03.05
#    ✅ [수집 완료] 2024.03.05 - 5건
#    📅 [날짜 처리 중] 2024.03.06
#    ✅ [수집 완료] 2024.03.06 - 2건
#    📅 [날짜 처리 중] 2024.03.07
#    ✅ [수집 완료] 2024.03.07 - 2건
#    📅 [날짜 처리 중] 2024.03.08
#    ✅ [수집 완료] 2024.03.08 - 1건
#    📅 [날짜 처리 중] 2024.03.09
#    📅 [날짜 처리 중] 2024.03.10
#    📅 [날짜 처리 중] 2024.03.11
#    ✅ [수집 완료] 2024.03.11 - 10건
#    📅 [날짜 처리 중] 2024.03.12
#    ✅ [수집 완료] 2024.03.12 - 1건
#    📅 [날짜 처리 중] 2024.03.13
#    ✅ [수집 완료] 2024.03.13 - 1건
#    📅 [날짜 처리 중] 2024.03.14
#    ✅ [수집 완료] 2024.03.14 - 7건
#    📅 [날짜 처리 중] 2024.03.15
#    ✅ [수집 완료] 2024.03.15 - 4건
#    📅 [날짜 처리 중] 2024.03.16
#    ✅ [수집 완료] 2024.03.16 - 1건
#    📅 [날짜 처리 중] 2024.03.17
#    ✅ [수집 완료] 2024.03.17 - 1건
#    📅 [날짜 처리 중] 2024.03.18
#    ✅ [수집 완료] 2024.03.18 - 6건
#    📅 [날짜 처리 중] 2024.03.19
#    ✅ [수집 완료] 2024.03.19 - 2건
#    📅 [날짜 처리 중] 2024.03.20
#    ✅ [수집 완료] 2024.03.20 - 4건
#    📅 [날짜 처리 중] 2024.03.21
#    ✅ [수집 완료] 2024.03.21 - 1건
#    📅 [날짜 처리 중] 2024.03.22
#    ✅ [수집 완료] 2024.03.22 - 1건
#    📅 [날짜 처리 중] 2024.03.23
#    📅 [날짜 처리 중] 2024.03.24
#    ✅ [수집 완료] 2024.03.24 - 1건
#    📅 [날짜 처리 중] 2024.03.25
#    ✅ [수집 완료] 2024.03.25 - 3건
#    📅 [날짜 처리 중] 2024.03.26
#    ✅ [수집 완료] 2024.03.26 - 2건
#    📅 [날짜 처리 중] 2024.03.27
#    ✅ [수집 완료] 2024.03.27 - 2건
#    📅 [날짜 처리 중] 2024.03.28
#    ✅ [수집 완료] 2024.03.28 - 1건
#    📅 [날짜 처리 중] 2024.03.29
#    ✅ [수집 완료] 2024.03.29 - 2건
#    📅 [날짜 처리 중] 2024.03.30
#    📅 [날짜 처리 중] 2024.03.31
#    📅 [날짜 처리 중] 2024.04.01
#    ✅ [수집 완료] 2024.04.01 - 9건
#    📅 [날짜 처리 중] 2024.04.02
#    ✅ [수집 완료] 2024.04.02 - 10건
#    📅 [날짜 처리 중] 2024.04.03
#    ✅ [수집 완료] 2024.04.03 - 7건
#    📅 [날짜 처리 중] 2024.04.04
#    ✅ [수집 완료] 2024.04.04 - 2건
#    📅 [날짜 처리 중] 2024.04.05
#    ✅ [수집 완료] 2024.04.05 - 3건
#    📅 [날짜 처리 중] 2024.04.06
#    ✅ [수집 완료] 2024.04.06 - 1건
#    📅 [날짜 처리 중] 2024.04.07
#    📅 [날짜 처리 중] 2024.04.08
#    ✅ [수집 완료] 2024.04.08 - 3건
#    📅 [날짜 처리 중] 2024.04.09
#    ✅ [수집 완료] 2024.04.09 - 2건
#    📅 [날짜 처리 중] 2024.04.10
#    ✅ [수집 완료] 2024.04.10 - 3건
#    📅 [날짜 처리 중] 2024.04.11
#    📅 [날짜 처리 중] 2024.04.12
#    📅 [날짜 처리 중] 2024.04.13
#    📅 [날짜 처리 중] 2024.04.14
#    ✅ [수집 완료] 2024.04.14 - 1건
#    📅 [날짜 처리 중] 2024.04.15
#    ✅ [수집 완료] 2024.04.15 - 3건
#    📅 [날짜 처리 중] 2024.04.16
#    ✅ [수집 완료] 2024.04.16 - 1건
#    📅 [날짜 처리 중] 2024.04.17
#    ✅ [수집 완료] 2024.04.17 - 1건
#    📅 [날짜 처리 중] 2024.04.18
#    ✅ [수집 완료] 2024.04.18 - 4건
#    📅 [날짜 처리 중] 2024.04.19
#    📅 [날짜 처리 중] 2024.04.20
#    ✅ [수집 완료] 2024.04.20 - 2건
#    📅 [날짜 처리 중] 2024.04.21
#    📅 [날짜 처리 중] 2024.04.22
#    ✅ [수집 완료] 2024.04.22 - 1건
#    📅 [날짜 처리 중] 2024.04.23
#    ✅ [수집 완료] 2024.04.23 - 5건
#    📅 [날짜 처리 중] 2024.04.24
#    ✅ [수집 완료] 2024.04.24 - 3건
#    📅 [날짜 처리 중] 2024.04.25
#    ✅ [수집 완료] 2024.04.25 - 1건
#    📅 [날짜 처리 중] 2024.04.26
#    ✅ [수집 완료] 2024.04.26 - 1건
#    📅 [날짜 처리 중] 2024.04.27
#    ✅ [수집 완료] 2024.04.27 - 1건
#    📅 [날짜 처리 중] 2024.04.28
#    📅 [날짜 처리 중] 2024.04.29
#    ✅ [수집 완료] 2024.04.29 - 2건
#    📅 [날짜 처리 중] 2024.04.30
#    ✅ [수집 완료] 2024.04.30 - 1건
#    📅 [날짜 처리 중] 2024.05.01
#    📅 [날짜 처리 중] 2024.05.02
#    ✅ [수집 완료] 2024.05.02 - 7건
#    📅 [날짜 처리 중] 2024.05.03
#    📅 [날짜 처리 중] 2024.05.04
#    ✅ [수집 완료] 2024.05.04 - 1건
#    📅 [날짜 처리 중] 2024.05.05
#    📅 [날짜 처리 중] 2024.05.06
#    📅 [날짜 처리 중] 2024.05.07
#    ✅ [수집 완료] 2024.05.07 - 1건
#    📅 [날짜 처리 중] 2024.05.08
#    ✅ [수집 완료] 2024.05.08 - 3건
#    📅 [날짜 처리 중] 2024.05.09
#    ✅ [수집 완료] 2024.05.09 - 4건
#    📅 [날짜 처리 중] 2024.05.10
#    📅 [날짜 처리 중] 2024.05.11
#    ✅ [수집 완료] 2024.05.11 - 2건
#    📅 [날짜 처리 중] 2024.05.12
#    📅 [날짜 처리 중] 2024.05.13
#    ✅ [수집 완료] 2024.05.13 - 2건
#    📅 [날짜 처리 중] 2024.05.14
#    ✅ [수집 완료] 2024.05.14 - 1건
#    📅 [날짜 처리 중] 2024.05.15
#    📅 [날짜 처리 중] 2024.05.16
#    ✅ [수집 완료] 2024.05.16 - 2건
#    📅 [날짜 처리 중] 2024.05.17
#    ✅ [수집 완료] 2024.05.17 - 1건
#    📅 [날짜 처리 중] 2024.05.18
#    ✅ [수집 완료] 2024.05.18 - 1건
#    📅 [날짜 처리 중] 2024.05.19
#    📅 [날짜 처리 중] 2024.05.20
#    ✅ [수집 완료] 2024.05.20 - 1건
#    📅 [날짜 처리 중] 2024.05.21
#    ✅ [수집 완료] 2024.05.21 - 6건
#    📅 [날짜 처리 중] 2024.05.22
#    ✅ [수집 완료] 2024.05.22 - 3건
#    📅 [날짜 처리 중] 2024.05.23
#    ✅ [수집 완료] 2024.05.23 - 6건
#    📅 [날짜 처리 중] 2024.05.24
#    ✅ [수집 완료] 2024.05.24 - 3건
#    📅 [날짜 처리 중] 2024.05.25
#    ✅ [수집 완료] 2024.05.25 - 2건
#    📅 [날짜 처리 중] 2024.05.26
#    📅 [날짜 처리 중] 2024.05.27
#    📅 [날짜 처리 중] 2024.05.28
#    📅 [날짜 처리 중] 2024.05.29
#    ✅ [수집 완료] 2024.05.29 - 7건
#    📅 [날짜 처리 중] 2024.05.30
#    ✅ [수집 완료] 2024.05.30 - 3건
#    📅 [날짜 처리 중] 2024.05.31
#    📅 [날짜 처리 중] 2024.06.01
#    📅 [날짜 처리 중] 2024.06.02
#    📅 [날짜 처리 중] 2024.06.03
#    ✅ [수집 완료] 2024.06.03 - 3건
#    📅 [날짜 처리 중] 2024.06.04
#    ✅ [수집 완료] 2024.06.04 - 7건
#    📅 [날짜 처리 중] 2024.06.05
#    ✅ [수집 완료] 2024.06.05 - 3건
#    📅 [날짜 처리 중] 2024.06.06
#    ✅ [수집 완료] 2024.06.06 - 1건
#    📅 [날짜 처리 중] 2024.06.07
#    ✅ [수집 완료] 2024.06.07 - 4건
#    📅 [날짜 처리 중] 2024.06.08
#    📅 [날짜 처리 중] 2024.06.09
#    ✅ [수집 완료] 2024.06.09 - 3건
#    📅 [날짜 처리 중] 2024.06.10
#    ✅ [수집 완료] 2024.06.10 - 3건
#    📅 [날짜 처리 중] 2024.06.11
#    📅 [날짜 처리 중] 2024.06.12
#    📅 [날짜 처리 중] 2024.06.13
#    📅 [날짜 처리 중] 2024.06.14
#    ✅ [수집 완료] 2024.06.14 - 3건
#    📅 [날짜 처리 중] 2024.06.15
#    ✅ [수집 완료] 2024.06.15 - 2건
#    📅 [날짜 처리 중] 2024.06.16
#    ✅ [수집 완료] 2024.06.16 - 1건
#    📅 [날짜 처리 중] 2024.06.17
#    ✅ [수집 완료] 2024.06.17 - 6건
#    📅 [날짜 처리 중] 2024.06.18
#    ✅ [수집 완료] 2024.06.18 - 3건
#    📅 [날짜 처리 중] 2024.06.19
#    ✅ [수집 완료] 2024.06.19 - 1건
#    📅 [날짜 처리 중] 2024.06.20
#    ✅ [수집 완료] 2024.06.20 - 3건
#    📅 [날짜 처리 중] 2024.06.21
#    ✅ [수집 완료] 2024.06.21 - 6건
#    📅 [날짜 처리 중] 2024.06.22
#    📅 [날짜 처리 중] 2024.06.23
#    ✅ [수집 완료] 2024.06.23 - 1건
#    📅 [날짜 처리 중] 2024.06.24
#    ✅ [수집 완료] 2024.06.24 - 10건
#    📅 [날짜 처리 중] 2024.06.25
#    ✅ [수집 완료] 2024.06.25 - 5건
#    📅 [날짜 처리 중] 2024.06.26
#    📅 [날짜 처리 중] 2024.06.27
#    ✅ [수집 완료] 2024.06.27 - 1건
#    📅 [날짜 처리 중] 2024.06.28
#    ✅ [수집 완료] 2024.06.28 - 1건
#    📅 [날짜 처리 중] 2024.06.29
#    ✅ [수집 완료] 2024.06.29 - 1건
#    📅 [날짜 처리 중] 2024.06.30
#    📅 [날짜 처리 중] 2024.07.01
#    ✅ [수집 완료] 2024.07.01 - 1건
#    📅 [날짜 처리 중] 2024.07.02
#    ✅ [수집 완료] 2024.07.02 - 5건
#    📅 [날짜 처리 중] 2024.07.03
#    ✅ [수집 완료] 2024.07.03 - 2건
#    📅 [날짜 처리 중] 2024.07.04
#    ✅ [수집 완료] 2024.07.04 - 2건
#    📅 [날짜 처리 중] 2024.07.05
#    📅 [날짜 처리 중] 2024.07.06
#    📅 [날짜 처리 중] 2024.07.07
#    📅 [날짜 처리 중] 2024.07.08
#    ✅ [수집 완료] 2024.07.08 - 2건
#    📅 [날짜 처리 중] 2024.07.09
#    📅 [날짜 처리 중] 2024.07.10
#    ✅ [수집 완료] 2024.07.10 - 2건
#    📅 [날짜 처리 중] 2024.07.11
#    📅 [날짜 처리 중] 2024.07.12
#    📅 [날짜 처리 중] 2024.07.13
#    📅 [날짜 처리 중] 2024.07.14
#    ✅ [수집 완료] 2024.07.14 - 1건
#    📅 [날짜 처리 중] 2024.07.15
#    📅 [날짜 처리 중] 2024.07.16
#    ✅ [수집 완료] 2024.07.16 - 2건
#    📅 [날짜 처리 중] 2024.07.17
#    ✅ [수집 완료] 2024.07.17 - 3건
#    📅 [날짜 처리 중] 2024.07.18
#    ✅ [수집 완료] 2024.07.18 - 1건
#    📅 [날짜 처리 중] 2024.07.19
#    ✅ [수집 완료] 2024.07.19 - 13건
#    📅 [날짜 처리 중] 2024.07.20
#    ✅ [수집 완료] 2024.07.20 - 2건
#    📅 [날짜 처리 중] 2024.07.21
#    ✅ [수집 완료] 2024.07.21 - 1건
#    📅 [날짜 처리 중] 2024.07.22
#    ✅ [수집 완료] 2024.07.22 - 2건
#    📅 [날짜 처리 중] 2024.07.23
#    ✅ [수집 완료] 2024.07.23 - 4건
#    📅 [날짜 처리 중] 2024.07.24
#    📅 [날짜 처리 중] 2024.07.25
#    ✅ [수집 완료] 2024.07.25 - 1건
#    📅 [날짜 처리 중] 2024.07.26
#    ✅ [수집 완료] 2024.07.26 - 4건
#    📅 [날짜 처리 중] 2024.07.27
#    📅 [날짜 처리 중] 2024.07.28
#    ✅ [수집 완료] 2024.07.28 - 1건
#    📅 [날짜 처리 중] 2024.07.29
#    ✅ [수집 완료] 2024.07.29 - 1건
#    📅 [날짜 처리 중] 2024.07.30
#    ✅ [수집 완료] 2024.07.30 - 2건
#    📅 [날짜 처리 중] 2024.07.31
#    ✅ [수집 완료] 2024.07.31 - 1건
#    📅 [날짜 처리 중] 2024.08.01
#    ✅ [수집 완료] 2024.08.01 - 4건
#    📅 [날짜 처리 중] 2024.08.02
#    ✅ [수집 완료] 2024.08.02 - 12건
#    📅 [날짜 처리 중] 2024.08.03
#    ✅ [수집 완료] 2024.08.03 - 4건
#    📅 [날짜 처리 중] 2024.08.04
#    ✅ [수집 완료] 2024.08.04 - 5건
#    📅 [날짜 처리 중] 2024.08.05
#    📅 [날짜 처리 중] 2024.08.06
#    ✅ [수집 완료] 2024.08.06 - 2건
#    📅 [날짜 처리 중] 2024.08.07
#    ✅ [수집 완료] 2024.08.07 - 1건
#    📅 [날짜 처리 중] 2024.08.08
#    ✅ [수집 완료] 2024.08.08 - 4건
#    📅 [날짜 처리 중] 2024.08.09
#    📅 [날짜 처리 중] 2024.08.10
#    ✅ [수집 완료] 2024.08.10 - 1건
#    📅 [날짜 처리 중] 2024.08.11
#    ✅ [수집 완료] 2024.08.11 - 1건
#    📅 [날짜 처리 중] 2024.08.12
#    📅 [날짜 처리 중] 2024.08.13
#    📅 [날짜 처리 중] 2024.08.14
#    ✅ [수집 완료] 2024.08.14 - 12건
#    📅 [날짜 처리 중] 2024.08.15
#    ✅ [수집 완료] 2024.08.15 - 7건
#    📅 [날짜 처리 중] 2024.08.16
#    ✅ [수집 완료] 2024.08.16 - 3건
#    📅 [날짜 처리 중] 2024.08.17
#    ✅ [수집 완료] 2024.08.17 - 2건
#    📅 [날짜 처리 중] 2024.08.18
#    📅 [날짜 처리 중] 2024.08.19
#    📅 [날짜 처리 중] 2024.08.20
#    ✅ [수집 완료] 2024.08.20 - 1건
#    📅 [날짜 처리 중] 2024.08.21
#    ✅ [수집 완료] 2024.08.21 - 11건
#    📅 [날짜 처리 중] 2024.08.22
#    ✅ [수집 완료] 2024.08.22 - 1건
#    📅 [날짜 처리 중] 2024.08.23
#    ✅ [수집 완료] 2024.08.23 - 2건
#    📅 [날짜 처리 중] 2024.08.24
#    📅 [날짜 처리 중] 2024.08.25
#    ✅ [수집 완료] 2024.08.25 - 4건
#    📅 [날짜 처리 중] 2024.08.26
#    ✅ [수집 완료] 2024.08.26 - 1건
#    📅 [날짜 처리 중] 2024.08.27
#    ✅ [수집 완료] 2024.08.27 - 2건
#    📅 [날짜 처리 중] 2024.08.28
#    📅 [날짜 처리 중] 2024.08.29
#    ✅ [수집 완료] 2024.08.29 - 1건
#    📅 [날짜 처리 중] 2024.08.30
#    ✅ [수집 완료] 2024.08.30 - 2건
#    📅 [날짜 처리 중] 2024.08.31
#    ✅ [수집 완료] 2024.08.31 - 1건
#    📅 [날짜 처리 중] 2024.09.01
#    📅 [날짜 처리 중] 2024.09.02
#    ✅ [수집 완료] 2024.09.02 - 10건
#    📅 [날짜 처리 중] 2024.09.03
#    ✅ [수집 완료] 2024.09.03 - 5건
#    📅 [날짜 처리 중] 2024.09.04
#    📅 [날짜 처리 중] 2024.09.05
#    ✅ [수집 완료] 2024.09.05 - 2건
#    📅 [날짜 처리 중] 2024.09.06
#    📅 [날짜 처리 중] 2024.09.07
#    ✅ [수집 완료] 2024.09.07 - 3건
#    📅 [날짜 처리 중] 2024.09.08
#    ✅ [수집 완료] 2024.09.08 - 2건
#    📅 [날짜 처리 중] 2024.09.09
#    📅 [날짜 처리 중] 2024.09.10
#    ✅ [수집 완료] 2024.09.10 - 3건
#    📅 [날짜 처리 중] 2024.09.11
#    ✅ [수집 완료] 2024.09.11 - 1건
#    📅 [날짜 처리 중] 2024.09.12
#    ✅ [수집 완료] 2024.09.12 - 4건
#    📅 [날짜 처리 중] 2024.09.13
#    ✅ [수집 완료] 2024.09.13 - 3건
#    📅 [날짜 처리 중] 2024.09.14
#    ✅ [수집 완료] 2024.09.14 - 1건
#    📅 [날짜 처리 중] 2024.09.15
#    📅 [날짜 처리 중] 2024.09.16
#    ✅ [수집 완료] 2024.09.16 - 2건
#    📅 [날짜 처리 중] 2024.09.17
#    ✅ [수집 완료] 2024.09.17 - 1건
#    📅 [날짜 처리 중] 2024.09.18
#    📅 [날짜 처리 중] 2024.09.19
#    ✅ [수집 완료] 2024.09.19 - 3건
#    📅 [날짜 처리 중] 2024.09.20
#    ✅ [수집 완료] 2024.09.20 - 1건
#    📅 [날짜 처리 중] 2024.09.21
#    ✅ [수집 완료] 2024.09.21 - 2건
#    📅 [날짜 처리 중] 2024.09.22
#    ✅ [수집 완료] 2024.09.22 - 3건
#    📅 [날짜 처리 중] 2024.09.23
#    📅 [날짜 처리 중] 2024.09.24
#    ✅ [수집 완료] 2024.09.24 - 1건
#    📅 [날짜 처리 중] 2024.09.25
#    ✅ [수집 완료] 2024.09.25 - 1건
#    📅 [날짜 처리 중] 2024.09.26
#    ✅ [수집 완료] 2024.09.26 - 1건
#    📅 [날짜 처리 중] 2024.09.27
#    ✅ [수집 완료] 2024.09.27 - 2건
#    📅 [날짜 처리 중] 2024.09.28
#    📅 [날짜 처리 중] 2024.09.29
#    📅 [날짜 처리 중] 2024.09.30
#    📅 [날짜 처리 중] 2024.10.01
#    📅 [날짜 처리 중] 2024.10.02
#    ✅ [수집 완료] 2024.10.02 - 1건
#    📅 [날짜 처리 중] 2024.10.03
#    📅 [날짜 처리 중] 2024.10.04
#    ✅ [수집 완료] 2024.10.04 - 5건
#    📅 [날짜 처리 중] 2024.10.05
#    ✅ [수집 완료] 2024.10.05 - 1건
#    📅 [날짜 처리 중] 2024.10.06
#    ✅ [수집 완료] 2024.10.06 - 1건
#    📅 [날짜 처리 중] 2024.10.07
#    📅 [날짜 처리 중] 2024.10.08
#    📅 [날짜 처리 중] 2024.10.09
#    ✅ [수집 완료] 2024.10.09 - 1건
#    📅 [날짜 처리 중] 2024.10.10
#    ✅ [수집 완료] 2024.10.10 - 1건
#    📅 [날짜 처리 중] 2024.10.11
#    📅 [날짜 처리 중] 2024.10.12
#    📅 [날짜 처리 중] 2024.10.13
#    📅 [날짜 처리 중] 2024.10.14
#    ✅ [수집 완료] 2024.10.14 - 1건
#    📅 [날짜 처리 중] 2024.10.15
#    ✅ [수집 완료] 2024.10.15 - 2건
#    📅 [날짜 처리 중] 2024.10.16
#    ✅ [수집 완료] 2024.10.16 - 1건
#    📅 [날짜 처리 중] 2024.10.17
#    📅 [날짜 처리 중] 2024.10.18
#    📅 [날짜 처리 중] 2024.10.19
#    ✅ [수집 완료] 2024.10.19 - 2건
#    📅 [날짜 처리 중] 2024.10.20
#    📅 [날짜 처리 중] 2024.10.21
#    📅 [날짜 처리 중] 2024.10.22
#    📅 [날짜 처리 중] 2024.10.23
#    ✅ [수집 완료] 2024.10.23 - 2건
#    📅 [날짜 처리 중] 2024.10.24
#    ✅ [수집 완료] 2024.10.24 - 1건
#    📅 [날짜 처리 중] 2024.10.25
#    ✅ [수집 완료] 2024.10.25 - 5건
#    📅 [날짜 처리 중] 2024.10.26
#    ✅ [수집 완료] 2024.10.26 - 1건
#    📅 [날짜 처리 중] 2024.10.27
#    📅 [날짜 처리 중] 2024.10.28
#    📅 [날짜 처리 중] 2024.10.29
#    ✅ [수집 완료] 2024.10.29 - 1건
#    📅 [날짜 처리 중] 2024.10.30
#    📅 [날짜 처리 중] 2024.10.31
#    📅 [날짜 처리 중] 2024.11.01
#    📅 [날짜 처리 중] 2024.11.02
#    📅 [날짜 처리 중] 2024.11.03
#    📅 [날짜 처리 중] 2024.11.04
#    ✅ [수집 완료] 2024.11.04 - 6건
#    📅 [날짜 처리 중] 2024.11.05
#    ✅ [수집 완료] 2024.11.05 - 1건
#    📅 [날짜 처리 중] 2024.11.06
#    ✅ [수집 완료] 2024.11.06 - 1건
#    📅 [날짜 처리 중] 2024.11.07
#    ✅ [수집 완료] 2024.11.07 - 10건
#    📅 [날짜 처리 중] 2024.11.08
#    ✅ [수집 완료] 2024.11.08 - 2건
#    📅 [날짜 처리 중] 2024.11.09
#    📅 [날짜 처리 중] 2024.11.10
#    ✅ [수집 완료] 2024.11.10 - 1건
#    📅 [날짜 처리 중] 2024.11.11
#    ✅ [수집 완료] 2024.11.11 - 2건
#    📅 [날짜 처리 중] 2024.11.12
#    ✅ [수집 완료] 2024.11.12 - 1건
#    📅 [날짜 처리 중] 2024.11.13
#    📅 [날짜 처리 중] 2024.11.14
#    ✅ [수집 완료] 2024.11.14 - 2건
#    📅 [날짜 처리 중] 2024.11.15
#    ✅ [수집 완료] 2024.11.15 - 3건
#    📅 [날짜 처리 중] 2024.11.16
#    📅 [날짜 처리 중] 2024.11.17
#    📅 [날짜 처리 중] 2024.11.18
#    ✅ [수집 완료] 2024.11.18 - 1건
#    📅 [날짜 처리 중] 2024.11.19
#    ✅ [수집 완료] 2024.11.19 - 1건
#    📅 [날짜 처리 중] 2024.11.20
#    ✅ [수집 완료] 2024.11.20 - 5건
#    📅 [날짜 처리 중] 2024.11.21
#    📅 [날짜 처리 중] 2024.11.22
#    ✅ [수집 완료] 2024.11.22 - 3건
#    📅 [날짜 처리 중] 2024.11.23
#    📅 [날짜 처리 중] 2024.11.24
#    📅 [날짜 처리 중] 2024.11.25
#    ✅ [수집 완료] 2024.11.25 - 2건
#    📅 [날짜 처리 중] 2024.11.26
#    📅 [날짜 처리 중] 2024.11.27
#    📅 [날짜 처리 중] 2024.11.28
#    ✅ [수집 완료] 2024.11.28 - 1건
#    📅 [날짜 처리 중] 2024.11.29
#    📅 [날짜 처리 중] 2024.11.30
#    📅 [날짜 처리 중] 2024.12.01
#    ✅ [수집 완료] 2024.12.01 - 2건
#    📅 [날짜 처리 중] 2024.12.02
#    ✅ [수집 완료] 2024.12.02 - 3건
#    📅 [날짜 처리 중] 2024.12.03
#    ✅ [수집 완료] 2024.12.03 - 8건
#    📅 [날짜 처리 중] 2024.12.04
#    ✅ [수집 완료] 2024.12.04 - 2건
#    📅 [날짜 처리 중] 2024.12.05
#    ✅ [수집 완료] 2024.12.05 - 1건
#    📅 [날짜 처리 중] 2024.12.06
#    📅 [날짜 처리 중] 2024.12.07
#    📅 [날짜 처리 중] 2024.12.08
#    📅 [날짜 처리 중] 2024.12.09
#    📅 [날짜 처리 중] 2024.12.10
#    ✅ [수집 완료] 2024.12.10 - 2건
#    📅 [날짜 처리 중] 2024.12.11
#    ✅ [수집 완료] 2024.12.11 - 3건
#    📅 [날짜 처리 중] 2024.12.12
#    ✅ [수집 완료] 2024.12.12 - 5건
#    📅 [날짜 처리 중] 2024.12.13
#    ✅ [수집 완료] 2024.12.13 - 13건
#    📅 [날짜 처리 중] 2024.12.14
#    ✅ [수집 완료] 2024.12.14 - 3건
#    📅 [날짜 처리 중] 2024.12.15
#    ✅ [수집 완료] 2024.12.15 - 1건
#    📅 [날짜 처리 중] 2024.12.16
#    ✅ [수집 완료] 2024.12.16 - 1건
#    📅 [날짜 처리 중] 2024.12.17
#    ✅ [수집 완료] 2024.12.17 - 1건
#    📅 [날짜 처리 중] 2024.12.18
#    ✅ [수집 완료] 2024.12.18 - 3건
#    📅 [날짜 처리 중] 2024.12.19
#    ✅ [수집 완료] 2024.12.19 - 3건
#    📅 [날짜 처리 중] 2024.12.20
#    ✅ [수집 완료] 2024.12.20 - 2건
#    📅 [날짜 처리 중] 2024.12.21
#    ✅ [수집 완료] 2024.12.21 - 1건
#    📅 [날짜 처리 중] 2024.12.22
#    📅 [날짜 처리 중] 2024.12.23
#    ✅ [수집 완료] 2024.12.23 - 3건
#    📅 [날짜 처리 중] 2024.12.24
#    ✅ [수집 완료] 2024.12.24 - 10건
#    📅 [날짜 처리 중] 2024.12.25
#    ✅ [수집 완료] 2024.12.25 - 5건
#    📅 [날짜 처리 중] 2024.12.26
#    ✅ [수집 완료] 2024.12.26 - 2건
#    📅 [날짜 처리 중] 2024.12.27
#    ✅ [수집 완료] 2024.12.27 - 2건
#    📅 [날짜 처리 중] 2024.12.28
#    📅 [날짜 처리 중] 2024.12.29
#    ✅ [수집 완료] 2024.12.29 - 2건
#    📅 [날짜 처리 중] 2024.12.30
#    ✅ [수집 완료] 2024.12.30 - 1건
#    📅 [날짜 처리 중] 2024.12.31
# 🌙 [대기] 다음 기업 전환 전 10초 대기...
#
# 📁 전체 완료! 총 691건의 뉴스가 저장되었습니다: 세진중공업_2024년_뉴스.csv
