# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from urllib.parse import quote
import random
import re

# 기업 리스트
companies = ["STX엔진"]

# 날짜 리스트 (2024년 전체)
dates = pd.date_range(start="2024-01-01", end="2024-12-31").strftime("%Y.%m.%d").tolist()

# 결과 저장용
results = []
seen = set()

# Chrome 옵션 설정
options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# 드라이버 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# 크롤링 시작
for company in companies:
    print(f"\n🔍 [기업 시작] {company}")
    encoded_query = quote(company)

    for target_date in dates:
        print(f"   📅 [날짜 처리 중] {target_date}")
        display_date = target_date.replace(".", "")
        count_per_day = 0

        for start in range(1, 1000, 10):
            url = (
                f"https://search.naver.com/search.naver?where=news&query={encoded_query}"
                f"&sort=0&ds={target_date}&de={target_date}"
                f"&nso=so:r,p:from{display_date}to{display_date},a:all"
                f"&start={start}"
            )

            driver.get(url)
            time.sleep(random.uniform(2, 4))  # 페이지 로딩 대기

            try:
                news_elements = driver.find_elements(By.CSS_SELECTOR, "a.n6AJosQA40hUOAe_Vplg.cdv6mdm2_kpW2D6slkm6")
            except Exception as e:
                print(f"      ⚠️ 구조 탐색 실패 - {company} / {target_date} - {e}")
                break

            if not news_elements:
                break  # 뉴스 없으면 다음 날짜로

            for elem in news_elements:
                try:
                    url = elem.get_attribute("href")

                    # 내부 <span> 요소 탐색 (정확한 뉴스 제목 포함)
                    try:
                        span = elem.find_element(By.CSS_SELECTOR, "span.sds-comps-text-type-headline1")
                        raw_title = span.get_attribute("textContent").strip()
                    except:
                        continue  # 제목 span 없으면 skip

                    # 대괄호 [텍스트] 제거
                    cleaned_title = re.sub(r'\[.*?\]', '', raw_title).strip()

                    # 기업명 제거
                    cleaned_title = cleaned_title.replace(company, "").strip(", ").strip()

                    if not url or not cleaned_title:
                        continue

                    if (company, cleaned_title, url) in seen:
                        continue
                    seen.add((company, cleaned_title, url))

                    results.append({
                        "기업명": company,
                        "날짜": target_date,
                        "뉴스제목": cleaned_title,
                        "URL": url
                    })
                    count_per_day += 1
                except Exception as e:
                    print(f"      ⚠️ 추출 오류: {e}")
                    continue

        if count_per_day > 0:
            print(f"   ✅ [수집 완료] {target_date} - {count_per_day}건")

        time.sleep(random.uniform(1, 2))  # 날짜 간 대기

    print("🌙 [대기] 다음 기업 전환 전 10초 대기...")
    time.sleep(10)

# 드라이버 종료
driver.quit()

# 저장
output_filename = f"{companies[0]}_2024년_뉴스.csv"
df = pd.DataFrame(results)
df.to_csv(output_filename, index=False, encoding='utf-8-sig')
print(f"\n📁 전체 완료! 총 {len(df)}건의 뉴스가 저장되었습니다: {output_filename}")
# Out:
# 🔍 [기업 시작] STX엔진
#    📅 [날짜 처리 중] 2024.01.01
#    ✅ [수집 완료] 2024.01.01 - 3건
#    📅 [날짜 처리 중] 2024.01.02
#    📅 [날짜 처리 중] 2024.01.03
#    ✅ [수집 완료] 2024.01.03 - 9건
#    📅 [날짜 처리 중] 2024.01.04
#    ✅ [수집 완료] 2024.01.04 - 3건
#    📅 [날짜 처리 중] 2024.01.05
#    ✅ [수집 완료] 2024.01.05 - 2건
#    📅 [날짜 처리 중] 2024.01.06
#    📅 [날짜 처리 중] 2024.01.07
#    📅 [날짜 처리 중] 2024.01.08
#    ✅ [수집 완료] 2024.01.08 - 8건
#    📅 [날짜 처리 중] 2024.01.09
#    ✅ [수집 완료] 2024.01.09 - 4건
#    📅 [날짜 처리 중] 2024.01.10
#    ✅ [수집 완료] 2024.01.10 - 4건
#    📅 [날짜 처리 중] 2024.01.11
#    ✅ [수집 완료] 2024.01.11 - 1건
#    📅 [날짜 처리 중] 2024.01.12
#    ✅ [수집 완료] 2024.01.12 - 3건
#    📅 [날짜 처리 중] 2024.01.13
#    📅 [날짜 처리 중] 2024.01.14
#    ✅ [수집 완료] 2024.01.14 - 6건
#    📅 [날짜 처리 중] 2024.01.15
#    ✅ [수집 완료] 2024.01.15 - 2건
#    📅 [날짜 처리 중] 2024.01.16
#    ✅ [수집 완료] 2024.01.16 - 1건
#    📅 [날짜 처리 중] 2024.01.17
#    ✅ [수집 완료] 2024.01.17 - 3건
#    📅 [날짜 처리 중] 2024.01.18
#    ✅ [수집 완료] 2024.01.18 - 3건
#    📅 [날짜 처리 중] 2024.01.19
#    ✅ [수집 완료] 2024.01.19 - 2건
#    📅 [날짜 처리 중] 2024.01.20
#    ✅ [수집 완료] 2024.01.20 - 1건
#    📅 [날짜 처리 중] 2024.01.21
#    📅 [날짜 처리 중] 2024.01.22
#    📅 [날짜 처리 중] 2024.01.23
#    ✅ [수집 완료] 2024.01.23 - 1건
#    📅 [날짜 처리 중] 2024.01.24
#    ✅ [수집 완료] 2024.01.24 - 2건
#    📅 [날짜 처리 중] 2024.01.25
#    📅 [날짜 처리 중] 2024.01.26
#    ✅ [수집 완료] 2024.01.26 - 2건
#    📅 [날짜 처리 중] 2024.01.27
#    📅 [날짜 처리 중] 2024.01.28
#    📅 [날짜 처리 중] 2024.01.29
#    📅 [날짜 처리 중] 2024.01.30
#    📅 [날짜 처리 중] 2024.01.31
#    ✅ [수집 완료] 2024.01.31 - 3건
#    📅 [날짜 처리 중] 2024.02.01
#    ✅ [수집 완료] 2024.02.01 - 2건
#    📅 [날짜 처리 중] 2024.02.02
#    ✅ [수집 완료] 2024.02.02 - 8건
#    📅 [날짜 처리 중] 2024.02.03
#    ✅ [수집 완료] 2024.02.03 - 1건
#    📅 [날짜 처리 중] 2024.02.04
#    📅 [날짜 처리 중] 2024.02.05
#    ✅ [수집 완료] 2024.02.05 - 1건
#    📅 [날짜 처리 중] 2024.02.06
#    ✅ [수집 완료] 2024.02.06 - 1건
#    📅 [날짜 처리 중] 2024.02.07
#    ✅ [수집 완료] 2024.02.07 - 5건
#    📅 [날짜 처리 중] 2024.02.08
#    ✅ [수집 완료] 2024.02.08 - 1건
#    📅 [날짜 처리 중] 2024.02.09
#    📅 [날짜 처리 중] 2024.02.10
#    ✅ [수집 완료] 2024.02.10 - 1건
#    📅 [날짜 처리 중] 2024.02.11
#    ✅ [수집 완료] 2024.02.11 - 2건
#    📅 [날짜 처리 중] 2024.02.12
#    📅 [날짜 처리 중] 2024.02.13
#    ✅ [수집 완료] 2024.02.13 - 2건
#    📅 [날짜 처리 중] 2024.02.14
#    ✅ [수집 완료] 2024.02.14 - 1건
#    📅 [날짜 처리 중] 2024.02.15
#    ✅ [수집 완료] 2024.02.15 - 1건
#    📅 [날짜 처리 중] 2024.02.16
#    ✅ [수집 완료] 2024.02.16 - 1건
#    📅 [날짜 처리 중] 2024.02.17
#    📅 [날짜 처리 중] 2024.02.18
#    📅 [날짜 처리 중] 2024.02.19
#    ✅ [수집 완료] 2024.02.19 - 3건
#    📅 [날짜 처리 중] 2024.02.20
#    📅 [날짜 처리 중] 2024.02.21
#    ✅ [수집 완료] 2024.02.21 - 3건
#    📅 [날짜 처리 중] 2024.02.22
#    ✅ [수집 완료] 2024.02.22 - 4건
#    📅 [날짜 처리 중] 2024.02.23
#    ✅ [수집 완료] 2024.02.23 - 3건
#    📅 [날짜 처리 중] 2024.02.24
#    📅 [날짜 처리 중] 2024.02.25
#    📅 [날짜 처리 중] 2024.02.26
#    ✅ [수집 완료] 2024.02.26 - 2건
#    📅 [날짜 처리 중] 2024.02.27
#    ✅ [수집 완료] 2024.02.27 - 4건
#    📅 [날짜 처리 중] 2024.02.28
#    ✅ [수집 완료] 2024.02.28 - 2건
#    📅 [날짜 처리 중] 2024.02.29
#    ✅ [수집 완료] 2024.02.29 - 2건
#    📅 [날짜 처리 중] 2024.03.01
#    ✅ [수집 완료] 2024.03.01 - 3건
#    📅 [날짜 처리 중] 2024.03.02
#    ✅ [수집 완료] 2024.03.02 - 1건
#    📅 [날짜 처리 중] 2024.03.03
#    ✅ [수집 완료] 2024.03.03 - 1건
#    📅 [날짜 처리 중] 2024.03.04
#    ✅ [수집 완료] 2024.03.04 - 5건
#    📅 [날짜 처리 중] 2024.03.05
#    ✅ [수집 완료] 2024.03.05 - 6건
#    📅 [날짜 처리 중] 2024.03.06
#    ✅ [수집 완료] 2024.03.06 - 3건
#    📅 [날짜 처리 중] 2024.03.07
#    ✅ [수집 완료] 2024.03.07 - 3건
#    📅 [날짜 처리 중] 2024.03.08
#    ✅ [수집 완료] 2024.03.08 - 1건
#    📅 [날짜 처리 중] 2024.03.09
#    📅 [날짜 처리 중] 2024.03.10
#    📅 [날짜 처리 중] 2024.03.11
#    ✅ [수집 완료] 2024.03.11 - 1건
#    📅 [날짜 처리 중] 2024.03.12
#    ✅ [수집 완료] 2024.03.12 - 2건
#    📅 [날짜 처리 중] 2024.03.13
#    ✅ [수집 완료] 2024.03.13 - 2건
#    📅 [날짜 처리 중] 2024.03.14
#    ✅ [수집 완료] 2024.03.14 - 3건
#    📅 [날짜 처리 중] 2024.03.15
#    ✅ [수집 완료] 2024.03.15 - 4건
#    📅 [날짜 처리 중] 2024.03.16
#    📅 [날짜 처리 중] 2024.03.17
#    ✅ [수집 완료] 2024.03.17 - 1건
#    📅 [날짜 처리 중] 2024.03.18
#    ✅ [수집 완료] 2024.03.18 - 7건
#    📅 [날짜 처리 중] 2024.03.19
#    📅 [날짜 처리 중] 2024.03.20
#    ✅ [수집 완료] 2024.03.20 - 3건
#    📅 [날짜 처리 중] 2024.03.21
#    ✅ [수집 완료] 2024.03.21 - 4건
#    📅 [날짜 처리 중] 2024.03.22
#    ✅ [수집 완료] 2024.03.22 - 3건
#    📅 [날짜 처리 중] 2024.03.23
#    ✅ [수집 완료] 2024.03.23 - 1건
#    📅 [날짜 처리 중] 2024.03.24
#    ✅ [수집 완료] 2024.03.24 - 1건
#    📅 [날짜 처리 중] 2024.03.25
#    ✅ [수집 완료] 2024.03.25 - 1건
#    📅 [날짜 처리 중] 2024.03.26
#    ✅ [수집 완료] 2024.03.26 - 2건
#    📅 [날짜 처리 중] 2024.03.27
#    ✅ [수집 완료] 2024.03.27 - 2건
#    📅 [날짜 처리 중] 2024.03.28
#    ✅ [수집 완료] 2024.03.28 - 1건
#    📅 [날짜 처리 중] 2024.03.29
#    ✅ [수집 완료] 2024.03.29 - 3건
#    📅 [날짜 처리 중] 2024.03.30
#    📅 [날짜 처리 중] 2024.03.31
#    ✅ [수집 완료] 2024.03.31 - 2건
#    📅 [날짜 처리 중] 2024.04.01
#    ✅ [수집 완료] 2024.04.01 - 7건
#    📅 [날짜 처리 중] 2024.04.02
#    ✅ [수집 완료] 2024.04.02 - 8건
#    📅 [날짜 처리 중] 2024.04.03
#    ✅ [수집 완료] 2024.04.03 - 3건
#    📅 [날짜 처리 중] 2024.04.04
#    ✅ [수집 완료] 2024.04.04 - 2건
#    📅 [날짜 처리 중] 2024.04.05
#    ✅ [수집 완료] 2024.04.05 - 2건
#    📅 [날짜 처리 중] 2024.04.06
#    ✅ [수집 완료] 2024.04.06 - 1건
#    📅 [날짜 처리 중] 2024.04.07
#    ✅ [수집 완료] 2024.04.07 - 1건
#    📅 [날짜 처리 중] 2024.04.08
#    ✅ [수집 완료] 2024.04.08 - 2건
#    📅 [날짜 처리 중] 2024.04.09
#    ✅ [수집 완료] 2024.04.09 - 2건
#    📅 [날짜 처리 중] 2024.04.10
#    📅 [날짜 처리 중] 2024.04.11
#    📅 [날짜 처리 중] 2024.04.12
#    📅 [날짜 처리 중] 2024.04.13
#    ✅ [수집 완료] 2024.04.13 - 1건
#    📅 [날짜 처리 중] 2024.04.14
#    ✅ [수집 완료] 2024.04.14 - 2건
#    📅 [날짜 처리 중] 2024.04.15
#    ✅ [수집 완료] 2024.04.15 - 15건
#    📅 [날짜 처리 중] 2024.04.16
#    ✅ [수집 완료] 2024.04.16 - 6건
#    📅 [날짜 처리 중] 2024.04.17
#    ✅ [수집 완료] 2024.04.17 - 1건
#    📅 [날짜 처리 중] 2024.04.18
#    ✅ [수집 완료] 2024.04.18 - 4건
#    📅 [날짜 처리 중] 2024.04.19
#    ✅ [수집 완료] 2024.04.19 - 2건
#    📅 [날짜 처리 중] 2024.04.20
#    ✅ [수집 완료] 2024.04.20 - 5건
#    📅 [날짜 처리 중] 2024.04.21
#    📅 [날짜 처리 중] 2024.04.22
#    ✅ [수집 완료] 2024.04.22 - 1건
#    📅 [날짜 처리 중] 2024.04.23
#    ✅ [수집 완료] 2024.04.23 - 9건
#    📅 [날짜 처리 중] 2024.04.24
#    ✅ [수집 완료] 2024.04.24 - 16건
#    📅 [날짜 처리 중] 2024.04.25
#    ✅ [수집 완료] 2024.04.25 - 10건
#    📅 [날짜 처리 중] 2024.04.26
#    ✅ [수집 완료] 2024.04.26 - 2건
#    📅 [날짜 처리 중] 2024.04.27
#    ✅ [수집 완료] 2024.04.27 - 3건
#    📅 [날짜 처리 중] 2024.04.28
#    ✅ [수집 완료] 2024.04.28 - 1건
#    📅 [날짜 처리 중] 2024.04.29
#    ✅ [수집 완료] 2024.04.29 - 1건
#    📅 [날짜 처리 중] 2024.04.30
#    ✅ [수집 완료] 2024.04.30 - 1건
#    📅 [날짜 처리 중] 2024.05.01
#    📅 [날짜 처리 중] 2024.05.02
#    ✅ [수집 완료] 2024.05.02 - 7건
#    📅 [날짜 처리 중] 2024.05.03
#    📅 [날짜 처리 중] 2024.05.04
#    📅 [날짜 처리 중] 2024.05.05
#    📅 [날짜 처리 중] 2024.05.06
#    📅 [날짜 처리 중] 2024.05.07
#    ✅ [수집 완료] 2024.05.07 - 2건
#    📅 [날짜 처리 중] 2024.05.08
#    ✅ [수집 완료] 2024.05.08 - 3건
#    📅 [날짜 처리 중] 2024.05.09
#    ✅ [수집 완료] 2024.05.09 - 3건
#    📅 [날짜 처리 중] 2024.05.10
#    📅 [날짜 처리 중] 2024.05.11
#    ✅ [수집 완료] 2024.05.11 - 2건
#    📅 [날짜 처리 중] 2024.05.12
#    📅 [날짜 처리 중] 2024.05.13
#    ✅ [수집 완료] 2024.05.13 - 2건
#    📅 [날짜 처리 중] 2024.05.14
#    ✅ [수집 완료] 2024.05.14 - 2건
#    📅 [날짜 처리 중] 2024.05.15
#    ✅ [수집 완료] 2024.05.15 - 1건
#    📅 [날짜 처리 중] 2024.05.16
#    ✅ [수집 완료] 2024.05.16 - 2건
#    📅 [날짜 처리 중] 2024.05.17
#    📅 [날짜 처리 중] 2024.05.18
#    📅 [날짜 처리 중] 2024.05.19
#    📅 [날짜 처리 중] 2024.05.20
#    ✅ [수집 완료] 2024.05.20 - 3건
#    📅 [날짜 처리 중] 2024.05.21
#    ✅ [수집 완료] 2024.05.21 - 1건
#    📅 [날짜 처리 중] 2024.05.22
#    ✅ [수집 완료] 2024.05.22 - 2건
#    📅 [날짜 처리 중] 2024.05.23
#    ✅ [수집 완료] 2024.05.23 - 3건
#    📅 [날짜 처리 중] 2024.05.24
#    ✅ [수집 완료] 2024.05.24 - 2건
#    📅 [날짜 처리 중] 2024.05.25
#    ✅ [수집 완료] 2024.05.25 - 2건
#    📅 [날짜 처리 중] 2024.05.26
#    📅 [날짜 처리 중] 2024.05.27
#    ✅ [수집 완료] 2024.05.27 - 2건
#    📅 [날짜 처리 중] 2024.05.28
#    ✅ [수집 완료] 2024.05.28 - 2건
#    📅 [날짜 처리 중] 2024.05.29
#    ✅ [수집 완료] 2024.05.29 - 1건
#    📅 [날짜 처리 중] 2024.05.30
#    ✅ [수집 완료] 2024.05.30 - 1건
#    📅 [날짜 처리 중] 2024.05.31
#    📅 [날짜 처리 중] 2024.06.01
#    📅 [날짜 처리 중] 2024.06.02
#    📅 [날짜 처리 중] 2024.06.03
#    ✅ [수집 완료] 2024.06.03 - 2건
#    📅 [날짜 처리 중] 2024.06.04
#    ✅ [수집 완료] 2024.06.04 - 6건
#    📅 [날짜 처리 중] 2024.06.05
#    ✅ [수집 완료] 2024.06.05 - 2건
#    📅 [날짜 처리 중] 2024.06.06
#    ✅ [수집 완료] 2024.06.06 - 1건
#    📅 [날짜 처리 중] 2024.06.07
#    ✅ [수집 완료] 2024.06.07 - 1건
#    📅 [날짜 처리 중] 2024.06.08
#    ✅ [수집 완료] 2024.06.08 - 1건
#    📅 [날짜 처리 중] 2024.06.09
#    📅 [날짜 처리 중] 2024.06.10
#    ✅ [수집 완료] 2024.06.10 - 13건
#    📅 [날짜 처리 중] 2024.06.11
#    ✅ [수집 완료] 2024.06.11 - 3건
#    📅 [날짜 처리 중] 2024.06.12
#    📅 [날짜 처리 중] 2024.06.13
#    ✅ [수집 완료] 2024.06.13 - 1건
#    📅 [날짜 처리 중] 2024.06.14
#    ✅ [수집 완료] 2024.06.14 - 2건
#    📅 [날짜 처리 중] 2024.06.15
#    📅 [날짜 처리 중] 2024.06.16
#    ✅ [수집 완료] 2024.06.16 - 1건
#    📅 [날짜 처리 중] 2024.06.17
#    ✅ [수집 완료] 2024.06.17 - 2건
#    📅 [날짜 처리 중] 2024.06.18
#    ✅ [수집 완료] 2024.06.18 - 1건
#    📅 [날짜 처리 중] 2024.06.19
#    ✅ [수집 완료] 2024.06.19 - 13건
#    📅 [날짜 처리 중] 2024.06.20
#    ✅ [수집 완료] 2024.06.20 - 7건
#    📅 [날짜 처리 중] 2024.06.21
#    ✅ [수집 완료] 2024.06.21 - 4건
#    📅 [날짜 처리 중] 2024.06.22
#    ✅ [수집 완료] 2024.06.22 - 2건
#    📅 [날짜 처리 중] 2024.06.23
#    📅 [날짜 처리 중] 2024.06.24
#    ✅ [수집 완료] 2024.06.24 - 3건
#    📅 [날짜 처리 중] 2024.06.25
#    ✅ [수집 완료] 2024.06.25 - 4건
#    📅 [날짜 처리 중] 2024.06.26
#    ✅ [수집 완료] 2024.06.26 - 1건
#    📅 [날짜 처리 중] 2024.06.27
#    ✅ [수집 완료] 2024.06.27 - 1건
#    📅 [날짜 처리 중] 2024.06.28
#    📅 [날짜 처리 중] 2024.06.29
#    📅 [날짜 처리 중] 2024.06.30
#    📅 [날짜 처리 중] 2024.07.01
#    ✅ [수집 완료] 2024.07.01 - 1건
#    📅 [날짜 처리 중] 2024.07.02
#    ✅ [수집 완료] 2024.07.02 - 8건
#    📅 [날짜 처리 중] 2024.07.03
#    ✅ [수집 완료] 2024.07.03 - 1건
#    📅 [날짜 처리 중] 2024.07.04
#    ✅ [수집 완료] 2024.07.04 - 1건
#    📅 [날짜 처리 중] 2024.07.05
#    ✅ [수집 완료] 2024.07.05 - 1건
#    📅 [날짜 처리 중] 2024.07.06
#    📅 [날짜 처리 중] 2024.07.07
#    📅 [날짜 처리 중] 2024.07.08
#    ✅ [수집 완료] 2024.07.08 - 1건
#    📅 [날짜 처리 중] 2024.07.09
#    ✅ [수집 완료] 2024.07.09 - 1건
#    📅 [날짜 처리 중] 2024.07.10
#    ✅ [수집 완료] 2024.07.10 - 2건
#    📅 [날짜 처리 중] 2024.07.11
#    ✅ [수집 완료] 2024.07.11 - 2건
#    📅 [날짜 처리 중] 2024.07.12
#    📅 [날짜 처리 중] 2024.07.13
#    📅 [날짜 처리 중] 2024.07.14
#    📅 [날짜 처리 중] 2024.07.15
#    ✅ [수집 완료] 2024.07.15 - 14건
#    📅 [날짜 처리 중] 2024.07.16
#    ✅ [수집 완료] 2024.07.16 - 10건
#    📅 [날짜 처리 중] 2024.07.17
#    ✅ [수집 완료] 2024.07.17 - 2건
#    📅 [날짜 처리 중] 2024.07.18
#    📅 [날짜 처리 중] 2024.07.19
#    📅 [날짜 처리 중] 2024.07.20
#    ✅ [수집 완료] 2024.07.20 - 1건
#    📅 [날짜 처리 중] 2024.07.21
#    📅 [날짜 처리 중] 2024.07.22
#    📅 [날짜 처리 중] 2024.07.23
#    ✅ [수집 완료] 2024.07.23 - 1건
#    📅 [날짜 처리 중] 2024.07.24
#    ✅ [수집 완료] 2024.07.24 - 2건
#    📅 [날짜 처리 중] 2024.07.25
#    ✅ [수집 완료] 2024.07.25 - 2건
#    📅 [날짜 처리 중] 2024.07.26
#    ✅ [수집 완료] 2024.07.26 - 9건
#    📅 [날짜 처리 중] 2024.07.27
#    ✅ [수집 완료] 2024.07.27 - 1건
#    📅 [날짜 처리 중] 2024.07.28
#    📅 [날짜 처리 중] 2024.07.29
#    ✅ [수집 완료] 2024.07.29 - 2건
#    📅 [날짜 처리 중] 2024.07.30
#    ✅ [수집 완료] 2024.07.30 - 1건
#    📅 [날짜 처리 중] 2024.07.31
#    ✅ [수집 완료] 2024.07.31 - 2건
#    📅 [날짜 처리 중] 2024.08.01
#    ✅ [수집 완료] 2024.08.01 - 3건
#    📅 [날짜 처리 중] 2024.08.02
#    ✅ [수집 완료] 2024.08.02 - 5건
#    📅 [날짜 처리 중] 2024.08.03
#    ✅ [수집 완료] 2024.08.03 - 1건
#    📅 [날짜 처리 중] 2024.08.04
#    ✅ [수집 완료] 2024.08.04 - 1건
#    📅 [날짜 처리 중] 2024.08.05
#    ✅ [수집 완료] 2024.08.05 - 1건
#    📅 [날짜 처리 중] 2024.08.06
#    ✅ [수집 완료] 2024.08.06 - 2건
#    📅 [날짜 처리 중] 2024.08.07
#    ✅ [수집 완료] 2024.08.07 - 1건
#    📅 [날짜 처리 중] 2024.08.08
#    ✅ [수집 완료] 2024.08.08 - 1건
#    📅 [날짜 처리 중] 2024.08.09
#    📅 [날짜 처리 중] 2024.08.10
#    📅 [날짜 처리 중] 2024.08.11
#    📅 [날짜 처리 중] 2024.08.12
#    📅 [날짜 처리 중] 2024.08.13
#    ✅ [수집 완료] 2024.08.13 - 2건
#    📅 [날짜 처리 중] 2024.08.14
#    ✅ [수집 완료] 2024.08.14 - 4건
#    📅 [날짜 처리 중] 2024.08.15
#    ✅ [수집 완료] 2024.08.15 - 1건
#    📅 [날짜 처리 중] 2024.08.16
#    ✅ [수집 완료] 2024.08.16 - 10건
#    📅 [날짜 처리 중] 2024.08.17
#    ✅ [수집 완료] 2024.08.17 - 3건
#    📅 [날짜 처리 중] 2024.08.18
#    ✅ [수집 완료] 2024.08.18 - 1건
#    📅 [날짜 처리 중] 2024.08.19
#    ✅ [수집 완료] 2024.08.19 - 5건
#    📅 [날짜 처리 중] 2024.08.20
#    ✅ [수집 완료] 2024.08.20 - 6건
#    📅 [날짜 처리 중] 2024.08.21
#    ✅ [수집 완료] 2024.08.21 - 2건
#    📅 [날짜 처리 중] 2024.08.22
#    ✅ [수집 완료] 2024.08.22 - 3건
#    📅 [날짜 처리 중] 2024.08.23
#    ✅ [수집 완료] 2024.08.23 - 1건
#    📅 [날짜 처리 중] 2024.08.24
#    📅 [날짜 처리 중] 2024.08.25
#    ✅ [수집 완료] 2024.08.25 - 1건
#    📅 [날짜 처리 중] 2024.08.26
#    📅 [날짜 처리 중] 2024.08.27
#    📅 [날짜 처리 중] 2024.08.28
#    ✅ [수집 완료] 2024.08.28 - 2건
#    📅 [날짜 처리 중] 2024.08.29
#    ✅ [수집 완료] 2024.08.29 - 7건
#    📅 [날짜 처리 중] 2024.08.30
#    ✅ [수집 완료] 2024.08.30 - 2건
#    📅 [날짜 처리 중] 2024.08.31
#    📅 [날짜 처리 중] 2024.09.01
#    ✅ [수집 완료] 2024.09.01 - 1건
#    📅 [날짜 처리 중] 2024.09.02
#    📅 [날짜 처리 중] 2024.09.03
#    ✅ [수집 완료] 2024.09.03 - 5건
#    📅 [날짜 처리 중] 2024.09.04
#    ✅ [수집 완료] 2024.09.04 - 1건
#    📅 [날짜 처리 중] 2024.09.05
#    📅 [날짜 처리 중] 2024.09.06
#    ✅ [수집 완료] 2024.09.06 - 2건
#    📅 [날짜 처리 중] 2024.09.07
#    ✅ [수집 완료] 2024.09.07 - 1건
#    📅 [날짜 처리 중] 2024.09.08
#    ✅ [수집 완료] 2024.09.08 - 2건
#    📅 [날짜 처리 중] 2024.09.09
#    📅 [날짜 처리 중] 2024.09.10
#    ✅ [수집 완료] 2024.09.10 - 1건
#    📅 [날짜 처리 중] 2024.09.11
#    ✅ [수집 완료] 2024.09.11 - 1건
#    📅 [날짜 처리 중] 2024.09.12
#    📅 [날짜 처리 중] 2024.09.13
#    ✅ [수집 완료] 2024.09.13 - 2건
#    📅 [날짜 처리 중] 2024.09.14
#    📅 [날짜 처리 중] 2024.09.15
#    ✅ [수집 완료] 2024.09.15 - 1건
#    📅 [날짜 처리 중] 2024.09.16
#    ✅ [수집 완료] 2024.09.16 - 1건
#    📅 [날짜 처리 중] 2024.09.17
#    ✅ [수집 완료] 2024.09.17 - 1건
#    📅 [날짜 처리 중] 2024.09.18
#    📅 [날짜 처리 중] 2024.09.19
#    ✅ [수집 완료] 2024.09.19 - 1건
#    📅 [날짜 처리 중] 2024.09.20
#    📅 [날짜 처리 중] 2024.09.21
#    ✅ [수집 완료] 2024.09.21 - 2건
#    📅 [날짜 처리 중] 2024.09.22
#    ✅ [수집 완료] 2024.09.22 - 2건
#    📅 [날짜 처리 중] 2024.09.23
#    ✅ [수집 완료] 2024.09.23 - 1건
#    📅 [날짜 처리 중] 2024.09.24
#    ✅ [수집 완료] 2024.09.24 - 2건
#    📅 [날짜 처리 중] 2024.09.25
#    ✅ [수집 완료] 2024.09.25 - 2건
#    📅 [날짜 처리 중] 2024.09.26
#    ✅ [수집 완료] 2024.09.26 - 4건
#    📅 [날짜 처리 중] 2024.09.27
#    ✅ [수집 완료] 2024.09.27 - 12건
#    📅 [날짜 처리 중] 2024.09.28
#    ✅ [수집 완료] 2024.09.28 - 5건
#    📅 [날짜 처리 중] 2024.09.29
#    ✅ [수집 완료] 2024.09.29 - 9건
#    📅 [날짜 처리 중] 2024.09.30
#    ✅ [수집 완료] 2024.09.30 - 8건
#    📅 [날짜 처리 중] 2024.10.01
#    ✅ [수집 완료] 2024.10.01 - 1건
#    📅 [날짜 처리 중] 2024.10.02
#    ✅ [수집 완료] 2024.10.02 - 13건
#    📅 [날짜 처리 중] 2024.10.03
#    ✅ [수집 완료] 2024.10.03 - 7건
#    📅 [날짜 처리 중] 2024.10.04
#    ✅ [수집 완료] 2024.10.04 - 9건
#    📅 [날짜 처리 중] 2024.10.05
#    ✅ [수집 완료] 2024.10.05 - 1건
#    📅 [날짜 처리 중] 2024.10.06
#    ✅ [수집 완료] 2024.10.06 - 3건
#    📅 [날짜 처리 중] 2024.10.07
#    ✅ [수집 완료] 2024.10.07 - 2건
#    📅 [날짜 처리 중] 2024.10.08
#    ✅ [수집 완료] 2024.10.08 - 2건
#    📅 [날짜 처리 중] 2024.10.09
#    ✅ [수집 완료] 2024.10.09 - 2건
#    📅 [날짜 처리 중] 2024.10.10
#    ✅ [수집 완료] 2024.10.10 - 3건
#    📅 [날짜 처리 중] 2024.10.11
#    ✅ [수집 완료] 2024.10.11 - 2건
#    📅 [날짜 처리 중] 2024.10.12
#    ✅ [수집 완료] 2024.10.12 - 1건
#    📅 [날짜 처리 중] 2024.10.13
#    ✅ [수집 완료] 2024.10.13 - 1건
#    📅 [날짜 처리 중] 2024.10.14
#    ✅ [수집 완료] 2024.10.14 - 3건
#    📅 [날짜 처리 중] 2024.10.15
#    ✅ [수집 완료] 2024.10.15 - 8건
#    📅 [날짜 처리 중] 2024.10.16
#    ✅ [수집 완료] 2024.10.16 - 7건
#    📅 [날짜 처리 중] 2024.10.17
#    ✅ [수집 완료] 2024.10.17 - 4건
#    📅 [날짜 처리 중] 2024.10.18
#    ✅ [수집 완료] 2024.10.18 - 2건
#    📅 [날짜 처리 중] 2024.10.19
#    ✅ [수집 완료] 2024.10.19 - 2건
#    📅 [날짜 처리 중] 2024.10.20
#    ✅ [수집 완료] 2024.10.20 - 2건
#    📅 [날짜 처리 중] 2024.10.21
#    ✅ [수집 완료] 2024.10.21 - 1건
#    📅 [날짜 처리 중] 2024.10.22
#    ✅ [수집 완료] 2024.10.22 - 1건
#    📅 [날짜 처리 중] 2024.10.23
#    ✅ [수집 완료] 2024.10.23 - 1건
#    📅 [날짜 처리 중] 2024.10.24
#    ✅ [수집 완료] 2024.10.24 - 2건
#    📅 [날짜 처리 중] 2024.10.25
#    ✅ [수집 완료] 2024.10.25 - 3건
#    📅 [날짜 처리 중] 2024.10.26
#    📅 [날짜 처리 중] 2024.10.27
#    ✅ [수집 완료] 2024.10.27 - 1건
#    📅 [날짜 처리 중] 2024.10.28
#    📅 [날짜 처리 중] 2024.10.29
#    ✅ [수집 완료] 2024.10.29 - 4건
#    📅 [날짜 처리 중] 2024.10.30
#    ✅ [수집 완료] 2024.10.30 - 3건
#    📅 [날짜 처리 중] 2024.10.31
#    ✅ [수집 완료] 2024.10.31 - 4건
#    📅 [날짜 처리 중] 2024.11.01
#    ✅ [수집 완료] 2024.11.01 - 2건
#    📅 [날짜 처리 중] 2024.11.02
#    ✅ [수집 완료] 2024.11.02 - 1건
#    📅 [날짜 처리 중] 2024.11.03
#    ✅ [수집 완료] 2024.11.03 - 1건
#    📅 [날짜 처리 중] 2024.11.04
#    ✅ [수집 완료] 2024.11.04 - 8건
#    📅 [날짜 처리 중] 2024.11.05
#    ✅ [수집 완료] 2024.11.05 - 2건
#    📅 [날짜 처리 중] 2024.11.06
#    ✅ [수집 완료] 2024.11.06 - 3건
#    📅 [날짜 처리 중] 2024.11.07
#    ✅ [수집 완료] 2024.11.07 - 10건
#    📅 [날짜 처리 중] 2024.11.08
#    📅 [날짜 처리 중] 2024.11.09
#    📅 [날짜 처리 중] 2024.11.10
#    📅 [날짜 처리 중] 2024.11.11
#    ✅ [수집 완료] 2024.11.11 - 10건
#    📅 [날짜 처리 중] 2024.11.12
#    ✅ [수집 완료] 2024.11.12 - 8건
#    📅 [날짜 처리 중] 2024.11.13
#    ✅ [수집 완료] 2024.11.13 - 2건
#    📅 [날짜 처리 중] 2024.11.14
#    ✅ [수집 완료] 2024.11.14 - 2건
#    📅 [날짜 처리 중] 2024.11.15
#    📅 [날짜 처리 중] 2024.11.16
#    ✅ [수집 완료] 2024.11.16 - 2건
#    📅 [날짜 처리 중] 2024.11.17
#    ✅ [수집 완료] 2024.11.17 - 1건
#    📅 [날짜 처리 중] 2024.11.18
#    📅 [날짜 처리 중] 2024.11.19
#    ✅ [수집 완료] 2024.11.19 - 2건
#    📅 [날짜 처리 중] 2024.11.20
#    ✅ [수집 완료] 2024.11.20 - 3건
#    📅 [날짜 처리 중] 2024.11.21
#    📅 [날짜 처리 중] 2024.11.22
#    ✅ [수집 완료] 2024.11.22 - 11건
#    📅 [날짜 처리 중] 2024.11.23
#    ✅ [수집 완료] 2024.11.23 - 1건
#    📅 [날짜 처리 중] 2024.11.24
#    ✅ [수집 완료] 2024.11.24 - 4건
#    📅 [날짜 처리 중] 2024.11.25
#    ✅ [수집 완료] 2024.11.25 - 3건
#    📅 [날짜 처리 중] 2024.11.26
#    ✅ [수집 완료] 2024.11.26 - 1건
#    📅 [날짜 처리 중] 2024.11.27
#    ✅ [수집 완료] 2024.11.27 - 7건
#    📅 [날짜 처리 중] 2024.11.28
#    ✅ [수집 완료] 2024.11.28 - 3건
#    📅 [날짜 처리 중] 2024.11.29
#    ✅ [수집 완료] 2024.11.29 - 2건
#    📅 [날짜 처리 중] 2024.11.30
#    📅 [날짜 처리 중] 2024.12.01
#    ✅ [수집 완료] 2024.12.01 - 1건
#    📅 [날짜 처리 중] 2024.12.02
#    ✅ [수집 완료] 2024.12.02 - 1건
#    📅 [날짜 처리 중] 2024.12.03
#    ✅ [수집 완료] 2024.12.03 - 10건
#    📅 [날짜 처리 중] 2024.12.04
#    ✅ [수집 완료] 2024.12.04 - 3건
#    📅 [날짜 처리 중] 2024.12.05
#    ✅ [수집 완료] 2024.12.05 - 4건
#    📅 [날짜 처리 중] 2024.12.06
#    ✅ [수집 완료] 2024.12.06 - 1건
#    📅 [날짜 처리 중] 2024.12.07
#    📅 [날짜 처리 중] 2024.12.08
#    📅 [날짜 처리 중] 2024.12.09
#    📅 [날짜 처리 중] 2024.12.10
#    ✅ [수집 완료] 2024.12.10 - 3건
#    📅 [날짜 처리 중] 2024.12.11
#    ✅ [수집 완료] 2024.12.11 - 5건
#    📅 [날짜 처리 중] 2024.12.12
#    ✅ [수집 완료] 2024.12.12 - 1건
#    📅 [날짜 처리 중] 2024.12.13
#    📅 [날짜 처리 중] 2024.12.14
#    ✅ [수집 완료] 2024.12.14 - 1건
#    📅 [날짜 처리 중] 2024.12.15
#    📅 [날짜 처리 중] 2024.12.16
#    ✅ [수집 완료] 2024.12.16 - 1건
#    📅 [날짜 처리 중] 2024.12.17
#    ✅ [수집 완료] 2024.12.17 - 2건
#    📅 [날짜 처리 중] 2024.12.18
#    ✅ [수집 완료] 2024.12.18 - 1건
#    📅 [날짜 처리 중] 2024.12.19
#    ✅ [수집 완료] 2024.12.19 - 4건
#    📅 [날짜 처리 중] 2024.12.20
#    📅 [날짜 처리 중] 2024.12.21
#    ✅ [수집 완료] 2024.12.21 - 1건
#    📅 [날짜 처리 중] 2024.12.22
#    📅 [날짜 처리 중] 2024.12.23
#    ✅ [수집 완료] 2024.12.23 - 6건
#    📅 [날짜 처리 중] 2024.12.24
#    📅 [날짜 처리 중] 2024.12.25
#    📅 [날짜 처리 중] 2024.12.26
#    ✅ [수집 완료] 2024.12.26 - 10건
#    📅 [날짜 처리 중] 2024.12.27
#    ✅ [수집 완료] 2024.12.27 - 1건
#    📅 [날짜 처리 중] 2024.12.28
#    📅 [날짜 처리 중] 2024.12.29
#    ✅ [수집 완료] 2024.12.29 - 3건
#    📅 [날짜 처리 중] 2024.12.30
#    📅 [날짜 처리 중] 2024.12.31
# 🌙 [대기] 다음 기업 전환 전 10초 대기...
#
# 📁 전체 완료! 총 841건의 뉴스가 저장되었습니다: STX엔진_2024년_뉴스.csv
